# %%
# Import MINST data
import input_data
mnist = input_data.read_data_sets("/tmp/data/", one_hot=True)

import tensorflow as tf

# Parameters
learning_rate = 0.001
training_iters = 100000
batch_size = 128
display_step = 10

# Network Parameters
n_input = 784 # MNIST data input (img shape: 28*28)
n_classes = 10 # MNIST total classes (0-9 digits)
dropout = 0.75 # Dropout, probability to keep units

# tf Graph input
x = tf.placeholder(tf.float32, [None, n_input])
y = tf.placeholder(tf.float32, [None, n_classes])
keep_prob = tf.placeholder(tf.float32) #dropout (keep probability)

# Create model
def conv2d(img, w, b):
    return tf.nn.relu(tf.nn.bias_add\
                      (tf.nn.conv2d(img, w,\
                                    strides=[1, 1, 1, 1],\
                                    padding='VALID'),b))

def max_pool(img, k):
    return tf.nn.max_pool(img, \
                          ksize=[1, k, k, 1],\
                          strides=[1, k, k, 1],\
                          padding='VALID')

# Store layers weight & bias

wc1 = tf.Variable(tf.random_normal([5, 5, 1, 32])) # 5x5 conv, 1 input, 32 outputs
wc2 = tf.Variable(tf.random_normal([5, 5, 32, 64])) # 5x5 conv, 32 inputs, 64 outputs
wd1 = tf.Variable(tf.random_normal([4*4*64, 1024])) # fully connected, 7*7*64 inputs, 1024 outputs
wout = tf.Variable(tf.random_normal([1024, n_classes])) # 1024 inputs, 10 outputs (class prediction)


bc1 = tf.Variable(tf.random_normal([32]))
bc2 = tf.Variable(tf.random_normal([64]))
bd1 = tf.Variable(tf.random_normal([1024]))
bout = tf.Variable(tf.random_normal([n_classes]))


# Construct model
_X = tf.reshape(x, shape=[-1, 28, 28, 1])


# Convolution Layer
conv1 = conv2d(_X,wc1,bc1)

# Max Pooling (down-sampling)
conv1 = max_pool(conv1, k=2)

# Apply Dropout
conv1 = tf.nn.dropout(conv1,keep_prob)


# Convolution Layer
conv2 = conv2d(conv1,wc2,bc2)

# Max Pooling (down-sampling)
conv2 = max_pool(conv2, k=2)

# Apply Dropout
conv2 = tf.nn.dropout(conv2, keep_prob)


# Fully connected layer
dense1 = tf.reshape(conv2, [-1, wd1.get_shape().as_list()[0]]) # Reshape conv2 output to fit dense layer input
dense1 = tf.nn.relu(tf.add(tf.matmul(dense1, wd1),bd1)) # Relu activation
dense1 = tf.nn.dropout(dense1, keep_prob) # Apply Dropout

# Output, class prediction
pred = tf.add(tf.matmul(dense1, wout), bout)

#pred = conv_net(x, weights, biases, keep_prob)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(pred, y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.initialize_all_variables()

# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        batch_xs, batch_ys = mnist.train.next_batch(batch_size)
        # Fit training using batch data
        sess.run(optimizer, feed_dict={x: batch_xs, y: batch_ys, keep_prob: dropout})
        if step % display_step == 0:
            # Calculate batch accuracy
            acc = sess.run(accuracy, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
            # Calculate batch loss
            loss = sess.run(cost, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.})
            print("Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(acc))
        step += 1
    print("Optimization Finished!")
    # Calculate accuracy for 256 mnist test images
    print("Testing Accuracy:", sess.run(accuracy, feed_dict={x: mnist.test.images[:256], y: mnist.test.labels[:256], keep_prob: 1.}))
# Out:
# Extracting /tmp/data/train-images-idx3-ubyte.gz
# Extracting /tmp/data/train-labels-idx1-ubyte.gz
# Extracting /tmp/data/t10k-images-idx3-ubyte.gz
# /usr/lib/python2.7/gzip.py:275: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   chunk = self.extrabuf[offset: offset + size]
# input_data.py:35: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   data = data.reshape(num_images, rows, cols, 1)
# Extracting /tmp/data/t10k-labels-idx1-ubyte.gz
# Iter 1280, Minibatch Loss= 25693.914062, Training Accuracy= 0.14062
# Iter 2560, Minibatch Loss= 18872.279297, Training Accuracy= 0.27344
# Iter 3840, Minibatch Loss= 15100.345703, Training Accuracy= 0.35156
# Iter 5120, Minibatch Loss= 8933.720703, Training Accuracy= 0.45312
# Iter 6400, Minibatch Loss= 6353.813477, Training Accuracy= 0.57812
# Iter 7680, Minibatch Loss= 7140.174805, Training Accuracy= 0.57031
# Iter 8960, Minibatch Loss= 5230.358887, Training Accuracy= 0.63281
# Iter 10240, Minibatch Loss= 4188.399414, Training Accuracy= 0.64844
# Iter 11520, Minibatch Loss= 2351.420898, Training Accuracy= 0.71094
# Iter 12800, Minibatch Loss= 5517.427246, Training Accuracy= 0.63281
# Iter 14080, Minibatch Loss= 2533.511963, Training Accuracy= 0.71875
# Iter 15360, Minibatch Loss= 2431.142578, Training Accuracy= 0.77344
# Iter 16640, Minibatch Loss= 2467.577148, Training Accuracy= 0.76562
# Iter 17920, Minibatch Loss= 2552.356689, Training Accuracy= 0.71875
# Iter 19200, Minibatch Loss= 1881.038818, Training Accuracy= 0.80469
# Iter 20480, Minibatch Loss= 935.484985, Training Accuracy= 0.87500
# Iter 21760, Minibatch Loss= 4496.171875, Training Accuracy= 0.72656
# Iter 23040, Minibatch Loss= 1264.458618, Training Accuracy= 0.90625
# Iter 24320, Minibatch Loss= 1917.299072, Training Accuracy= 0.76562
# Iter 25600, Minibatch Loss= 1675.049316, Training Accuracy= 0.75000
# Iter 26880, Minibatch Loss= 1128.127197, Training Accuracy= 0.84375
# Iter 28160, Minibatch Loss= 1603.058105, Training Accuracy= 0.76562
# Iter 29440, Minibatch Loss= 1650.364990, Training Accuracy= 0.83594
# Iter 30720, Minibatch Loss= 893.867493, Training Accuracy= 0.83594
# Iter 32000, Minibatch Loss= 732.530457, Training Accuracy= 0.89062
# Iter 33280, Minibatch Loss= 1286.551025, Training Accuracy= 0.82812
# Iter 34560, Minibatch Loss= 792.228516, Training Accuracy= 0.85156
# Iter 35840, Minibatch Loss= 433.674133, Training Accuracy= 0.91406
# Iter 37120, Minibatch Loss= 1565.215454, Training Accuracy= 0.78906
# Iter 38400, Minibatch Loss= 293.699127, Training Accuracy= 0.93750
# Iter 39680, Minibatch Loss= 442.225494, Training Accuracy= 0.89844
# Iter 40960, Minibatch Loss= 969.459167, Training Accuracy= 0.80469
# Iter 42240, Minibatch Loss= 945.419800, Training Accuracy= 0.85156
# Iter 43520, Minibatch Loss= 507.933105, Training Accuracy= 0.85156
# Iter 44800, Minibatch Loss= 789.672241, Training Accuracy= 0.85938
# Iter 46080, Minibatch Loss= 668.798462, Training Accuracy= 0.86719
# Iter 47360, Minibatch Loss= 684.548096, Training Accuracy= 0.86719
# Iter 48640, Minibatch Loss= 920.261475, Training Accuracy= 0.85938
# Iter 49920, Minibatch Loss= 888.630005, Training Accuracy= 0.79688
# Iter 51200, Minibatch Loss= 604.854126, Training Accuracy= 0.87500
# Iter 52480, Minibatch Loss= 945.526001, Training Accuracy= 0.84375
# Iter 53760, Minibatch Loss= 268.920410, Training Accuracy= 0.93750
# Iter 55040, Minibatch Loss= 843.343384, Training Accuracy= 0.83594
# Iter 56320, Minibatch Loss= 477.970978, Training Accuracy= 0.89844
# Iter 57600, Minibatch Loss= 260.761475, Training Accuracy= 0.94531
# Iter 58880, Minibatch Loss= 362.573059, Training Accuracy= 0.91406
# Iter 60160, Minibatch Loss= 360.094360, Training Accuracy= 0.90625
# Iter 61440, Minibatch Loss= 363.928223, Training Accuracy= 0.86719
# Iter 62720, Minibatch Loss= 395.924652, Training Accuracy= 0.87500
# Iter 64000, Minibatch Loss= 457.777100, Training Accuracy= 0.88281
# Iter 65280, Minibatch Loss= 590.652710, Training Accuracy= 0.85938
# Iter 66560, Minibatch Loss= 377.017700, Training Accuracy= 0.89844
# Iter 67840, Minibatch Loss= 327.168701, Training Accuracy= 0.86719
# Iter 69120, Minibatch Loss= 730.478882, Training Accuracy= 0.85156
# Iter 70400, Minibatch Loss= 467.055267, Training Accuracy= 0.87500
# Iter 71680, Minibatch Loss= 365.803375, Training Accuracy= 0.85938
# Iter 72960, Minibatch Loss= 450.131042, Training Accuracy= 0.85156
# Iter 74240, Minibatch Loss= 543.524048, Training Accuracy= 0.87500
# Iter 75520, Minibatch Loss= 378.326843, Training Accuracy= 0.91406
# Iter 76800, Minibatch Loss= 513.602661, Training Accuracy= 0.88281
# Iter 78080, Minibatch Loss= 272.062042, Training Accuracy= 0.89062
# Iter 79360, Minibatch Loss= 224.795868, Training Accuracy= 0.91406
# Iter 80640, Minibatch Loss= 340.677917, Training Accuracy= 0.86719
# Iter 81920, Minibatch Loss= 555.029297, Training Accuracy= 0.84375
# Iter 83200, Minibatch Loss= 401.581482, Training Accuracy= 0.88281
# Iter 84480, Minibatch Loss= 260.903687, Training Accuracy= 0.88281
# Iter 85760, Minibatch Loss= 458.666992, Training Accuracy= 0.86719
# Iter 87040, Minibatch Loss= 333.821655, Training Accuracy= 0.88281
# Iter 88320, Minibatch Loss= 551.907227, Training Accuracy= 0.82812
# Iter 89600, Minibatch Loss= 465.639465, Training Accuracy= 0.83594
# Iter 90880, Minibatch Loss= 258.379272, Training Accuracy= 0.89844
# Iter 92160, Minibatch Loss= 339.523468, Training Accuracy= 0.91406
# Iter 93440, Minibatch Loss= 357.797607, Training Accuracy= 0.89844
# Iter 94720, Minibatch Loss= 400.643616, Training Accuracy= 0.85938
# Iter 96000, Minibatch Loss= 163.434052, Training Accuracy= 0.92188
# Iter 97280, Minibatch Loss= 344.340424, Training Accuracy= 0.87500
# Iter 98560, Minibatch Loss= 190.763901, Training Accuracy= 0.89062
# Iter 99840, Minibatch Loss= 501.725983, Training Accuracy= 0.89062
# Optimization Finished!
# ('Testing Accuracy:', 0.91015625)
